# %% [markdown]
# # ITMAL Exercise
#
# REVISIONS| |
# ---------| |
# 2018-0318| CEF, initial.
# 2018-0321| CEF, synced with MLP moon exercise.
# 2018-0323| CEF, minor updated and spell checked.
# 2019-0930| CEF, updated for ITMAL E19.
#
#
# ## Keras Multi-Layer Perceptrons (MLP's) on MNIST-data
#
#
# ### Qa Using a Keras MLP on the MNIST-data
#
# Now, make a Keras `Sequential` model and fit it to the MNIST data, re-using as much of the code form the `mlp_moon.ipynb` as you can.
#
# Then try to change the number of hidden layers and the neurons in each layer, looking for increases in test accuracy via ``score``.
#
# Publish your best score for your model in Blackboard, see link under L06. We use categorical accuracy for score---eventhough a $F_1$ score could say more. Publish you result like
# ```
#    ITMALGrpXY: score=0.76, a 10-20-30-20-10 MLP, takes looong to train
# ```
# or similar
#
#
# NOTE: you probably need to scale/normalize the MNIST data before a fit, and no 2D-decision boundaries can be drawn from the 784-dimension MNIST data.

# %%
fig_cnt = 0
# %matplotlib inline
from sklearn.datasets import fetch_openml

def MNIST_GetDataSet():
    # Load data from https://www.openml.org/d/554
    X, y = fetch_openml('mnist_784', return_X_y=1) # needs to return X, y, replace '??' with suitable parameters! 
    # Convert at scale (not always needed)
    #X = X / 255.
    return (X, y)

def MNIST_PlotDigit(data):
    import matplotlib
    import matplotlib.pyplot as plt
    global fig_cnt
    plt.figure(fig_cnt)
    fig_cnt += 1
    image = data.reshape(28, 28)
    plt.imshow(image, cmap = matplotlib.cm.binary, interpolation="nearest")
    plt.axis("off")
    plt.show()
    
X, y = MNIST_GetDataSet()

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.optimizers import Adam, SGD
from keras.utils import to_categorical

from sklearn.model_selection import train_test_split

import numpy as np
from time import time

np.random.seed(1337)
num_classes = 10
X = X/255.0 #normalise

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1337)
# convert class vectors to binary class matrices
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)
# Out:
# Using TensorFlow backend.

# %%
from libitmal import kernelfuns as itmalkernefuns
itmalkernefuns.EnableGPU()
# Out:
# WARNING:tensorflow:From C:\Users\thoma\Documents\AU_IKT\_MAL\Repo\MAL_E19\handin\Handin2\L06\libitmal\kernelfuns.py:42: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\thoma\Documents\AU_IKT\_MAL\Repo\MAL_E19\handin\Handin2\L06\libitmal\kernelfuns.py:45: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.

# %%
#from libitmal import kernelfuns as itmalkernelfuns
#itmalkernelfuns.EnableGPU()                              
#itmalkernelfuns.DisableGPU()   

from keras.layers import Dropout


# Build Keras model 
model = Sequential()
#model.add(Dense(input_dim=784, units=8, activation="tanh", kernel_initializer="normal"))
#model.add(Dense(units=2, activation="softmax", input_shape=(784,)))
model.add(Dropout(0.2, input_shape=(784,)))
model.add(Dense(units=128, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(units=64, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
#model.add(Dense(units=100, activation='sigmoid', input_shape=(784,)))
#model.add(Dropout(0.2))
#model.add(Dense(units=32, activation='relu'))
model.add(Dense(units=num_classes, activation='softmax'))



optimizer = SGD(lr=0.001)
model.compile(loss='categorical_crossentropy', 
              optimizer=optimizer,
              metrics=['categorical_accuracy', 'mean_squared_error', 'mean_absolute_error'])
model.summary()
# Make data


assert y.ndim==1
assert y_train.ndim==2
assert y_test.ndim ==2

# Train
VERBOSE     = 1
EPOCHS      = 100

start = time()
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size = 128, epochs=EPOCHS, verbose=VERBOSE)
t = time()-start

print(f"OK, training time={t:0.1f}")
# Out:
# WARNING:tensorflow:From C:\Users\thoma\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\thoma\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\thoma\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From C:\Users\thoma\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\thoma\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dropout_1 (Dropout)          (None, 784)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               100480
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                650
# =================================================================
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From C:\Users\thoma\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 49000 samples, validate on 21000 samples
# Epoch 1/100
# 49000/49000 [==============================] - 11s 217us/step - loss: 2.4044 - categorical_accuracy: 0.0983 - mean_squared_error: 0.0920 - mean_absolute_error: 0.1801 - val_loss: 2.3197 - val_categorical_accuracy: 0.0995 - val_mean_squared_error: 0.0903 - val_mean_absolute_error: 0.1800
# Epoch 2/100
# 49000/49000 [==============================] - 11s 223us/step - loss: 2.3657 - categorical_accuracy: 0.1009 - mean_squared_error: 0.0913 - mean_absolute_error: 0.1800 - val_loss: 2.3017 - val_categorical_accuracy: 0.1350 - val_mean_squared_error: 0.0900 - val_mean_absolute_error: 0.1799
# Epoch 3/100
# 49000/49000 [==============================] - 8s 157us/step - loss: 2.3508 - categorical_accuracy: 0.1069 - mean_squared_error: 0.0910 - mean_absolute_error: 0.1798 - val_loss: 2.2952 - val_categorical_accuracy: 0.1226 - val_mean_squared_error: 0.0898 - val_mean_absolute_error: 0.1798
# Epoch 4/100
# 49000/49000 [==============================] - 10s 202us/step - loss: 2.3483 - categorical_accuracy: 0.1052 - mean_squared_error: 0.0909 - mean_absolute_error: 0.1798 - val_loss: 2.2911 - val_categorical_accuracy: 0.1268 - val_mean_squared_error: 0.0898 - val_mean_absolute_error: 0.1797
# Epoch 5/100
# 49000/49000 [==============================] - 7s 152us/step - loss: 2.3426 - categorical_accuracy: 0.1065 - mean_squared_error: 0.0908 - mean_absolute_error: 0.1797 - val_loss: 2.2875 - val_categorical_accuracy: 0.1301 - val_mean_squared_error: 0.0897 - val_mean_absolute_error: 0.1797
# Epoch 6/100
# 49000/49000 [==============================] - 11s 221us/step - loss: 2.3380 - categorical_accuracy: 0.1097 - mean_squared_error: 0.0907 - mean_absolute_error: 0.1796 - val_loss: 2.2840 - val_categorical_accuracy: 0.1402 - val_mean_squared_error: 0.0896 - val_mean_absolute_error: 0.1796.3375 - categorical_accuracy: 0.1114 - mean_squared_error:
# Epoch 7/100
# 49000/49000 [==============================] - 8s 170us/step - loss: 2.3361 - categorical_accuracy: 0.1109 - mean_squared_error: 0.0907 - mean_absolute_error: 0.1796 - val_loss: 2.2805 - val_categorical_accuracy: 0.1450 - val_mean_squared_error: 0.0895 - val_mean_absolute_error: 0.1795
# Epoch 8/100
# 49000/49000 [==============================] - 12s 236us/step - loss: 2.3316 - categorical_accuracy: 0.1134 - mean_squared_error: 0.0906 - mean_absolute_error: 0.1795 - val_loss: 2.2771 - val_categorical_accuracy: 0.1567 - val_mean_squared_error: 0.0895 - val_mean_absolute_error: 0.1794
# Epoch 9/100
# 49000/49000 [==============================] - 10s 205us/step - loss: 2.3245 - categorical_accuracy: 0.1184 - mean_squared_error: 0.0905 - mean_absolute_error: 0.1794 - val_loss: 2.2737 - val_categorical_accuracy: 0.1666 - val_mean_squared_error: 0.0894 - val_mean_absolute_error: 0.1794
# Epoch 10/100
# 49000/49000 [==============================] - 7s 151us/step - loss: 2.3236 - categorical_accuracy: 0.1177 - mean_squared_error: 0.0904 - mean_absolute_error: 0.1794 - val_loss: 2.2701 - val_categorical_accuracy: 0.1814 - val_mean_squared_error: 0.0893 - val_mean_absolute_error: 0.1793
# Epoch 11/100
# 49000/49000 [==============================] - 9s 185us/step - loss: 2.3185 - categorical_accuracy: 0.1211 - mean_squared_error: 0.0903 - mean_absolute_error: 0.1793 - val_loss: 2.2667 - val_categorical_accuracy: 0.1990 - val_mean_squared_error: 0.0893 - val_mean_absolute_error: 0.1792
# Epoch 12/100
# 49000/49000 [==============================] - 7s 148us/step - loss: 2.3145 - categorical_accuracy: 0.1240 - mean_squared_error: 0.0903 - mean_absolute_error: 0.1792 - val_loss: 2.2632 - val_categorical_accuracy: 0.2133 - val_mean_squared_error: 0.0892 - val_mean_absolute_error: 0.1791
# Epoch 13/100
# 49000/49000 [==============================] - 10s 198us/step - loss: 2.3118 - categorical_accuracy: 0.1261 - mean_squared_error: 0.0902 - mean_absolute_error: 0.1792 - val_loss: 2.2597 - val_categorical_accuracy: 0.2304 - val_mean_squared_error: 0.0891 - val_mean_absolute_error: 0.1791
# Epoch 14/100
# 49000/49000 [==============================] - 9s 175us/step - loss: 2.3077 - categorical_accuracy: 0.1270 - mean_squared_error: 0.0901 - mean_absolute_error: 0.1791 - val_loss: 2.2562 - val_categorical_accuracy: 0.2372 - val_mean_squared_error: 0.0890 - val_mean_absolute_error: 0.1790
# Epoch 15/100
# 49000/49000 [==============================] - 11s 218us/step - loss: 2.3070 - categorical_accuracy: 0.1284 - mean_squared_error: 0.0901 - mean_absolute_error: 0.1791 - val_loss: 2.2527 - val_categorical_accuracy: 0.2747 - val_mean_squared_error: 0.0890 - val_mean_absolute_error: 0.1789
# Epoch 16/100
# 49000/49000 [==============================] - 9s 174us/step - loss: 2.2964 - categorical_accuracy: 0.1333 - mean_squared_error: 0.0899 - mean_absolute_error: 0.1789 - val_loss: 2.2492 - val_categorical_accuracy: 0.2896 - val_mean_squared_error: 0.0889 - val_mean_absolute_error: 0.1788
# Epoch 17/100
# 49000/49000 [==============================] - 8s 160us/step - loss: 2.2959 - categorical_accuracy: 0.1343 - mean_squared_error: 0.0899 - mean_absolute_error: 0.1789 - val_loss: 2.2455 - val_categorical_accuracy: 0.3063 - val_mean_squared_error: 0.0888 - val_mean_absolute_error: 0.1788
# Epoch 18/100
# 49000/49000 [==============================] - 14s 276us/step - loss: 2.2908 - categorical_accuracy: 0.1370 - mean_squared_error: 0.0898 - mean_absolute_error: 0.1788 - val_loss: 2.2420 - val_categorical_accuracy: 0.3150 - val_mean_squared_error: 0.0887 - val_mean_absolute_error: 0.1787
# Epoch 19/100
# 49000/49000 [==============================] - 7s 137us/step - loss: 2.2868 - categorical_accuracy: 0.1417 - mean_squared_error: 0.0897 - mean_absolute_error: 0.1787 - val_loss: 2.2383 - val_categorical_accuracy: 0.3373 - val_mean_squared_error: 0.0886 - val_mean_absolute_error: 0.1786
# Epoch 20/100
# 49000/49000 [==============================] - 8s 160us/step - loss: 2.2843 - categorical_accuracy: 0.1424 - mean_squared_error: 0.0896 - mean_absolute_error: 0.1786 - val_loss: 2.2346 - val_categorical_accuracy: 0.3497 - val_mean_squared_error: 0.0886 - val_mean_absolute_error: 0.1785
# Epoch 21/100
# 49000/49000 [==============================] - 6s 125us/step - loss: 2.2778 - categorical_accuracy: 0.1490 - mean_squared_error: 0.0895 - mean_absolute_error: 0.1785 - val_loss: 2.2308 - val_categorical_accuracy: 0.3720 - val_mean_squared_error: 0.0885 - val_mean_absolute_error: 0.1784
# Epoch 22/100
# 49000/49000 [==============================] - 8s 156us/step - loss: 2.2737 - categorical_accuracy: 0.1495 - mean_squared_error: 0.0894 - mean_absolute_error: 0.1784 - val_loss: 2.2270 - val_categorical_accuracy: 0.3901 - val_mean_squared_error: 0.0884 - val_mean_absolute_error: 0.1783
# Epoch 23/100
# 49000/49000 [==============================] - 7s 134us/step - loss: 2.2722 - categorical_accuracy: 0.1488 - mean_squared_error: 0.0894 - mean_absolute_error: 0.1784 - val_loss: 2.2232 - val_categorical_accuracy: 0.3874 - val_mean_squared_error: 0.0883 - val_mean_absolute_error: 0.1783
# Epoch 24/100
# 49000/49000 [==============================] - 7s 143us/step - loss: 2.2646 - categorical_accuracy: 0.1573 - mean_squared_error: 0.0892 - mean_absolute_error: 0.1782 - val_loss: 2.2192 - val_categorical_accuracy: 0.4100 - val_mean_squared_error: 0.0882 - val_mean_absolute_error: 0.1782
# Epoch 25/100
# 49000/49000 [==============================] - 7s 145us/step - loss: 2.2615 - categorical_accuracy: 0.1582 - mean_squared_error: 0.0891 - mean_absolute_error: 0.1782 - val_loss: 2.2152 - val_categorical_accuracy: 0.4141 - val_mean_squared_error: 0.0881 - val_mean_absolute_error: 0.1781
# Epoch 26/100
# 49000/49000 [==============================] - 6s 132us/step - loss: 2.2587 - categorical_accuracy: 0.1631 - mean_squared_error: 0.0890 - mean_absolute_error: 0.1781 - val_loss: 2.2112 - val_categorical_accuracy: 0.4148 - val_mean_squared_error: 0.0880 - val_mean_absolute_error: 0.1780 - categorical_accuracy: 0.1636 - mean_squared_error: 0.0890 - mean_absolut
# Epoch 27/100
# 49000/49000 [==============================] - 8s 162us/step - loss: 2.2549 - categorical_accuracy: 0.1660 - mean_squared_error: 0.0890 - mean_absolute_error: 0.1780 - val_loss: 2.2070 - val_categorical_accuracy: 0.4324 - val_mean_squared_error: 0.0879 - val_mean_absolute_error: 0.1779
# Epoch 28/100
# 49000/49000 [==============================] - 8s 158us/step - loss: 2.2496 - categorical_accuracy: 0.1713 - mean_squared_error: 0.0888 - mean_absolute_error: 0.1779 - val_loss: 2.2028 - val_categorical_accuracy: 0.4415 - val_mean_squared_error: 0.0879 - val_mean_absolute_error: 0.1778
# Epoch 29/100
# 49000/49000 [==============================] - 9s 192us/step - loss: 2.2453 - categorical_accuracy: 0.1737 - mean_squared_error: 0.0888 - mean_absolute_error: 0.1778 - val_loss: 2.1985 - val_categorical_accuracy: 0.4490 - val_mean_squared_error: 0.0878 - val_mean_absolute_error: 0.1777
# Epoch 30/100
# 49000/49000 [==============================] - 8s 157us/step - loss: 2.2404 - categorical_accuracy: 0.1770 - mean_squared_error: 0.0886 - mean_absolute_error: 0.1777 - val_loss: 2.1941 - val_categorical_accuracy: 0.4553 - val_mean_squared_error: 0.0877 - val_mean_absolute_error: 0.1776
# Epoch 31/100
# 49000/49000 [==============================] - 11s 215us/step - loss: 2.2368 - categorical_accuracy: 0.1804 - mean_squared_error: 0.0886 - mean_absolute_error: 0.1776 - val_loss: 2.1896 - val_categorical_accuracy: 0.4620 - val_mean_squared_error: 0.0875 - val_mean_absolute_error: 0.1775tegorical_accuracy: 0.1805 - mean_squared_error: 0.0886 - mean_absolute_error: 0
# Epoch 32/100
# 49000/49000 [==============================] - 11s 219us/step - loss: 2.2314 - categorical_accuracy: 0.1864 - mean_squared_error: 0.0884 - mean_absolute_error: 0.1775 - val_loss: 2.1850 - val_categorical_accuracy: 0.4723 - val_mean_squared_error: 0.0874 - val_mean_absolute_error: 0.1774
# Epoch 33/100
# 49000/49000 [==============================] - 8s 173us/step - loss: 2.2268 - categorical_accuracy: 0.1887 - mean_squared_error: 0.0883 - mean_absolute_error: 0.1774 - val_loss: 2.1804 - val_categorical_accuracy: 0.4760 - val_mean_squared_error: 0.0873 - val_mean_absolute_error: 0.1772
# Epoch 34/100
# 49000/49000 [==============================] - 9s 180us/step - loss: 2.2239 - categorical_accuracy: 0.1900 - mean_squared_error: 0.0883 - mean_absolute_error: 0.1773 - val_loss: 2.1756 - val_categorical_accuracy: 0.4797 - val_mean_squared_error: 0.0872 - val_mean_absolute_error: 0.1771
# Epoch 35/100
# 49000/49000 [==============================] - 7s 148us/step - loss: 2.2173 - categorical_accuracy: 0.1951 - mean_squared_error: 0.0881 - mean_absolute_error: 0.1772 - val_loss: 2.1707 - val_categorical_accuracy: 0.4919 - val_mean_squared_error: 0.0871 - val_mean_absolute_error: 0.1770
# Epoch 36/100
# 49000/49000 [==============================] - 10s 195us/step - loss: 2.2120 - categorical_accuracy: 0.1993 - mean_squared_error: 0.0880 - mean_absolute_error: 0.1771 - val_loss: 2.1657 - val_categorical_accuracy: 0.5004 - val_mean_squared_error: 0.0870 - val_mean_absolute_error: 0.1769
# Epoch 37/100
# 49000/49000 [==============================] - 7s 150us/step - loss: 2.2054 - categorical_accuracy: 0.2080 - mean_squared_error: 0.0879 - mean_absolute_error: 0.1769 - val_loss: 2.1605 - val_categorical_accuracy: 0.5055 - val_mean_squared_error: 0.0869 - val_mean_absolute_error: 0.1767
# Epoch 38/100
# 49000/49000 [==============================] - 9s 182us/step - loss: 2.2034 - categorical_accuracy: 0.2098 - mean_squared_error: 0.0878 - mean_absolute_error: 0.1768 - val_loss: 2.1552 - val_categorical_accuracy: 0.5111 - val_mean_squared_error: 0.0867 - val_mean_absolute_error: 0.1766
# Epoch 39/100
# 49000/49000 [==============================] - 8s 157us/step - loss: 2.1962 - categorical_accuracy: 0.2154 - mean_squared_error: 0.0876 - mean_absolute_error: 0.1767 - val_loss: 2.1498 - val_categorical_accuracy: 0.5134 - val_mean_squared_error: 0.0866 - val_mean_absolute_error: 0.1765
# Epoch 40/100
# 49000/49000 [==============================] - 10s 210us/step - loss: 2.1914 - categorical_accuracy: 0.2187 - mean_squared_error: 0.0875 - mean_absolute_error: 0.1765 - val_loss: 2.1443 - val_categorical_accuracy: 0.5153 - val_mean_squared_error: 0.0865 - val_mean_absolute_error: 0.1763
# Epoch 41/100
# 49000/49000 [==============================] - 12s 243us/step - loss: 2.1856 - categorical_accuracy: 0.2264 - mean_squared_error: 0.0874 - mean_absolute_error: 0.1764 - val_loss: 2.1386 - val_categorical_accuracy: 0.5247 - val_mean_squared_error: 0.0863 - val_mean_absolute_error: 0.1762
# Epoch 42/100
# 49000/49000 [==============================] - 8s 154us/step - loss: 2.1804 - categorical_accuracy: 0.2300 - mean_squared_error: 0.0872 - mean_absolute_error: 0.1762 - val_loss: 2.1328 - val_categorical_accuracy: 0.5288 - val_mean_squared_error: 0.0862 - val_mean_absolute_error: 0.1760
# Epoch 43/100
# 49000/49000 [==============================] - 10s 194us/step - loss: 2.1778 - categorical_accuracy: 0.2321 - mean_squared_error: 0.0872 - mean_absolute_error: 0.1762 - val_loss: 2.1268 - val_categorical_accuracy: 0.5319 - val_mean_squared_error: 0.0860 - val_mean_absolute_error: 0.1759
# Epoch 44/100
# 49000/49000 [==============================] - 8s 157us/step - loss: 2.1679 - categorical_accuracy: 0.2404 - mean_squared_error: 0.0870 - mean_absolute_error: 0.1759 - val_loss: 2.1206 - val_categorical_accuracy: 0.5351 - val_mean_squared_error: 0.0859 - val_mean_absolute_error: 0.1757
# Epoch 45/100
# 49000/49000 [==============================] - 8s 171us/step - loss: 2.1634 - categorical_accuracy: 0.2440 - mean_squared_error: 0.0868 - mean_absolute_error: 0.1758 - val_loss: 2.1143 - val_categorical_accuracy: 0.5389 - val_mean_squared_error: 0.0857 - val_mean_absolute_error: 0.1755: 2.1684 - categorical_accuracy: - ETA: 0s - loss: 2.1645 - categorical_accuracy: 0.2433 - mean_squared_error: 0.0869 - mean_absolute_erro
# Epoch 46/100
# 49000/49000 [==============================] - 7s 138us/step - loss: 2.1564 - categorical_accuracy: 0.2493 - mean_squared_error: 0.0867 - mean_absolute_error: 0.1756 - val_loss: 2.1078 - val_categorical_accuracy: 0.5417 - val_mean_squared_error: 0.0856 - val_mean_absolute_error: 0.1753
# Epoch 47/100
# 49000/49000 [==============================] - 8s 160us/step - loss: 2.1497 - categorical_accuracy: 0.2549 - mean_squared_error: 0.0865 - mean_absolute_error: 0.1754 - val_loss: 2.1011 - val_categorical_accuracy: 0.5441 - val_mean_squared_error: 0.0854 - val_mean_absolute_error: 0.1752
# Epoch 48/100
# 49000/49000 [==============================] - 6s 128us/step - loss: 2.1471 - categorical_accuracy: 0.2547 - mean_squared_error: 0.0864 - mean_absolute_error: 0.1753 - val_loss: 2.0943 - val_categorical_accuracy: 0.5450 - val_mean_squared_error: 0.0852 - val_mean_absolute_error: 0.1750
# Epoch 49/100
# 49000/49000 [==============================] - 8s 171us/step - loss: 2.1356 - categorical_accuracy: 0.2675 - mean_squared_error: 0.0862 - mean_absolute_error: 0.1750 - val_loss: 2.0872 - val_categorical_accuracy: 0.5480 - val_mean_squared_error: 0.0850 - val_mean_absolute_error: 0.1748
# Epoch 50/100
# 49000/49000 [==============================] - 7s 133us/step - loss: 2.1309 - categorical_accuracy: 0.2695 - mean_squared_error: 0.0860 - mean_absolute_error: 0.1749 - val_loss: 2.0800 - val_categorical_accuracy: 0.5483 - val_mean_squared_error: 0.0849 - val_mean_absolute_error: 0.1746
# Epoch 51/100
# 49000/49000 [==============================] - 7s 153us/step - loss: 2.1251 - categorical_accuracy: 0.2730 - mean_squared_error: 0.0859 - mean_absolute_error: 0.1747 - val_loss: 2.0726 - val_categorical_accuracy: 0.5508 - val_mean_squared_error: 0.0847 - val_mean_absolute_error: 0.1743
# Epoch 52/100
# 49000/49000 [==============================] - 7s 138us/step - loss: 2.1158 - categorical_accuracy: 0.2810 - mean_squared_error: 0.0856 - mean_absolute_error: 0.1744 - val_loss: 2.0650 - val_categorical_accuracy: 0.5547 - val_mean_squared_error: 0.0845 - val_mean_absolute_error: 0.1741
# Epoch 53/100
# 49000/49000 [==============================] - 6s 129us/step - loss: 2.1101 - categorical_accuracy: 0.2870 - mean_squared_error: 0.0855 - mean_absolute_error: 0.1743 - val_loss: 2.0572 - val_categorical_accuracy: 0.5577 - val_mean_squared_error: 0.0843 - val_mean_absolute_error: 0.1739
# Epoch 54/100
# 49000/49000 [==============================] - 8s 172us/step - loss: 2.1021 - categorical_accuracy: 0.2888 - mean_squared_error: 0.0853 - mean_absolute_error: 0.1740 - val_loss: 2.0492 - val_categorical_accuracy: 0.5580 - val_mean_squared_error: 0.0840 - val_mean_absolute_error: 0.1736
# Epoch 55/100
# 49000/49000 [==============================] - 7s 144us/step - loss: 2.0939 - categorical_accuracy: 0.2977 - mean_squared_error: 0.0851 - mean_absolute_error: 0.1738 - val_loss: 2.0410 - val_categorical_accuracy: 0.5601 - val_mean_squared_error: 0.0838 - val_mean_absolute_error: 0.1734
# Epoch 56/100
# 49000/49000 [==============================] - 9s 179us/step - loss: 2.0861 - categorical_accuracy: 0.3028 - mean_squared_error: 0.0849 - mean_absolute_error: 0.1735 - val_loss: 2.0326 - val_categorical_accuracy: 0.5604 - val_mean_squared_error: 0.0836 - val_mean_absolute_error: 0.1731
# Epoch 57/100
# 49000/49000 [==============================] - 7s 141us/step - loss: 2.0815 - categorical_accuracy: 0.3049 - mean_squared_error: 0.0847 - mean_absolute_error: 0.1734 - val_loss: 2.0240 - val_categorical_accuracy: 0.5598 - val_mean_squared_error: 0.0833 - val_mean_absolute_error: 0.1729
# Epoch 58/100
# 49000/49000 [==============================] - 9s 185us/step - loss: 2.0717 - categorical_accuracy: 0.3107 - mean_squared_error: 0.0845 - mean_absolute_error: 0.1730 - val_loss: 2.0152 - val_categorical_accuracy: 0.5664 - val_mean_squared_error: 0.0831 - val_mean_absolute_error: 0.1726
# Epoch 59/100
# 49000/49000 [==============================] - 7s 136us/step - loss: 2.0637 - categorical_accuracy: 0.3162 - mean_squared_error: 0.0843 - mean_absolute_error: 0.1728 - val_loss: 2.0062 - val_categorical_accuracy: 0.5669 - val_mean_squared_error: 0.0829 - val_mean_absolute_error: 0.1723
# Epoch 60/100
# 49000/49000 [==============================] - 8s 167us/step - loss: 2.0540 - categorical_accuracy: 0.3213 - mean_squared_error: 0.0840 - mean_absolute_error: 0.1725 - val_loss: 1.9970 - val_categorical_accuracy: 0.5666 - val_mean_squared_error: 0.0826 - val_mean_absolute_error: 0.1720
# Epoch 61/100
# 49000/49000 [==============================] - 7s 137us/step - loss: 2.0455 - categorical_accuracy: 0.3261 - mean_squared_error: 0.0838 - mean_absolute_error: 0.1722 - val_loss: 1.9876 - val_categorical_accuracy: 0.5714 - val_mean_squared_error: 0.0823 - val_mean_absolute_error: 0.1717
# Epoch 62/100
# 49000/49000 [==============================] - 9s 177us/step - loss: 2.0385 - categorical_accuracy: 0.3302 - mean_squared_error: 0.0836 - mean_absolute_error: 0.1719 - val_loss: 1.9779 - val_categorical_accuracy: 0.5736 - val_mean_squared_error: 0.0821 - val_mean_absolute_error: 0.1714
# Epoch 63/100
# 49000/49000 [==============================] - 7s 142us/step - loss: 2.0270 - categorical_accuracy: 0.3358 - mean_squared_error: 0.0832 - mean_absolute_error: 0.1716 - val_loss: 1.9681 - val_categorical_accuracy: 0.5711 - val_mean_squared_error: 0.0818 - val_mean_absolute_error: 0.1710
# Epoch 64/100
# 49000/49000 [==============================] - 8s 167us/step - loss: 2.0186 - categorical_accuracy: 0.3430 - mean_squared_error: 0.0830 - mean_absolute_error: 0.1713 - val_loss: 1.9580 - val_categorical_accuracy: 0.5727 - val_mean_squared_error: 0.0815 - val_mean_absolute_error: 0.1707
# Epoch 65/100
# 49000/49000 [==============================] - 9s 193us/step - loss: 2.0085 - categorical_accuracy: 0.3497 - mean_squared_error: 0.0827 - mean_absolute_error: 0.1709 - val_loss: 1.9478 - val_categorical_accuracy: 0.5743 - val_mean_squared_error: 0.0812 - val_mean_absolute_error: 0.1703
# Epoch 66/100
# 49000/49000 [==============================] - 9s 185us/step - loss: 2.0001 - categorical_accuracy: 0.3503 - mean_squared_error: 0.0825 - mean_absolute_error: 0.1706 - val_loss: 1.9373 - val_categorical_accuracy: 0.5764 - val_mean_squared_error: 0.0809 - val_mean_absolute_error: 0.1699
# Epoch 67/100
# 49000/49000 [==============================] - 8s 160us/step - loss: 1.9893 - categorical_accuracy: 0.3565 - mean_squared_error: 0.0822 - mean_absolute_error: 0.1702 - val_loss: 1.9267 - val_categorical_accuracy: 0.5789 - val_mean_squared_error: 0.0806 - val_mean_absolute_error: 0.1696
# Epoch 68/100
# 49000/49000 [==============================] - 9s 187us/step - loss: 1.9811 - categorical_accuracy: 0.3593 - mean_squared_error: 0.0820 - mean_absolute_error: 0.1699 - val_loss: 1.9158 - val_categorical_accuracy: 0.5806 - val_mean_squared_error: 0.0802 - val_mean_absolute_error: 0.1692
# Epoch 69/100
# 49000/49000 [==============================] - 10s 214us/step - loss: 1.9718 - categorical_accuracy: 0.3612 - mean_squared_error: 0.0817 - mean_absolute_error: 0.1696 - val_loss: 1.9049 - val_categorical_accuracy: 0.5817 - val_mean_squared_error: 0.0799 - val_mean_absolute_error: 0.1688
# Epoch 70/100
# 49000/49000 [==============================] - 8s 170us/step - loss: 1.9619 - categorical_accuracy: 0.3691 - mean_squared_error: 0.0814 - mean_absolute_error: 0.1692 - val_loss: 1.8937 - val_categorical_accuracy: 0.5830 - val_mean_squared_error: 0.0796 - val_mean_absolute_error: 0.1683
# Epoch 71/100
# 49000/49000 [==============================] - 10s 196us/step - loss: 1.9501 - categorical_accuracy: 0.3740 - mean_squared_error: 0.0811 - mean_absolute_error: 0.1687 - val_loss: 1.8824 - val_categorical_accuracy: 0.5861 - val_mean_squared_error: 0.0792 - val_mean_absolute_error: 0.1679
# Epoch 72/100
# 49000/49000 [==============================] - 6s 129us/step - loss: 1.9419 - categorical_accuracy: 0.3765 - mean_squared_error: 0.0808 - mean_absolute_error: 0.1684 - val_loss: 1.8710 - val_categorical_accuracy: 0.5870 - val_mean_squared_error: 0.0789 - val_mean_absolute_error: 0.1675
# Epoch 73/100
# 49000/49000 [==============================] - 8s 154us/step - loss: 1.9310 - categorical_accuracy: 0.3811 - mean_squared_error: 0.0805 - mean_absolute_error: 0.1680 - val_loss: 1.8594 - val_categorical_accuracy: 0.5878 - val_mean_squared_error: 0.0785 - val_mean_absolute_error: 0.1670
# Epoch 74/100
# 49000/49000 [==============================] - 6s 131us/step - loss: 1.9163 - categorical_accuracy: 0.3910 - mean_squared_error: 0.0801 - mean_absolute_error: 0.1675 - val_loss: 1.8476 - val_categorical_accuracy: 0.5901 - val_mean_squared_error: 0.0782 - val_mean_absolute_error: 0.1666
# Epoch 75/100
# 49000/49000 [==============================] - 6s 129us/step - loss: 1.9058 - categorical_accuracy: 0.3949 - mean_squared_error: 0.0798 - mean_absolute_error: 0.1670 - val_loss: 1.8357 - val_categorical_accuracy: 0.5925 - val_mean_squared_error: 0.0778 - val_mean_absolute_error: 0.1661
# Epoch 76/100
# 49000/49000 [==============================] - 8s 162us/step - loss: 1.8970 - categorical_accuracy: 0.3975 - mean_squared_error: 0.0795 - mean_absolute_error: 0.1667 - val_loss: 1.8237 - val_categorical_accuracy: 0.5932 - val_mean_squared_error: 0.0774 - val_mean_absolute_error: 0.1656
# Epoch 77/100
# 49000/49000 [==============================] - 7s 143us/step - loss: 1.8854 - categorical_accuracy: 0.4042 - mean_squared_error: 0.0792 - mean_absolute_error: 0.1662 - val_loss: 1.8116 - val_categorical_accuracy: 0.5946 - val_mean_squared_error: 0.0770 - val_mean_absolute_error: 0.1651
# Epoch 78/100
# 49000/49000 [==============================] - 8s 161us/step - loss: 1.8768 - categorical_accuracy: 0.4022 - mean_squared_error: 0.0789 - mean_absolute_error: 0.1657 - val_loss: 1.7994 - val_categorical_accuracy: 0.5964 - val_mean_squared_error: 0.0766 - val_mean_absolute_error: 0.1646
# Epoch 79/100
# 49000/49000 [==============================] - 6s 132us/step - loss: 1.8651 - categorical_accuracy: 0.4086 - mean_squared_error: 0.0785 - mean_absolute_error: 0.1653 - val_loss: 1.7872 - val_categorical_accuracy: 0.5982 - val_mean_squared_error: 0.0762 - val_mean_absolute_error: 0.1641
# Epoch 80/100
# 49000/49000 [==============================] - 8s 161us/step - loss: 1.8541 - categorical_accuracy: 0.4121 - mean_squared_error: 0.0782 - mean_absolute_error: 0.1648 - val_loss: 1.7748 - val_categorical_accuracy: 0.6013 - val_mean_squared_error: 0.0758 - val_mean_absolute_error: 0.1635
# Epoch 81/100
# 49000/49000 [==============================] - 7s 134us/step - loss: 1.8422 - categorical_accuracy: 0.4181 - mean_squared_error: 0.0778 - mean_absolute_error: 0.1643 - val_loss: 1.7624 - val_categorical_accuracy: 0.6027 - val_mean_squared_error: 0.0754 - val_mean_absolute_error: 0.1630
# Epoch 82/100
# 49000/49000 [==============================] - 9s 178us/step - loss: 1.8315 - categorical_accuracy: 0.4226 - mean_squared_error: 0.0775 - mean_absolute_error: 0.1638 - val_loss: 1.7500 - val_categorical_accuracy: 0.6057 - val_mean_squared_error: 0.0750 - val_mean_absolute_error: 0.1624
# Epoch 83/100
# 49000/49000 [==============================] - 8s 154us/step - loss: 1.8219 - categorical_accuracy: 0.4221 - mean_squared_error: 0.0772 - mean_absolute_error: 0.1634 - val_loss: 1.7375 - val_categorical_accuracy: 0.6069 - val_mean_squared_error: 0.0746 - val_mean_absolute_error: 0.1619
# Epoch 84/100
# 49000/49000 [==============================] - 9s 185us/step - loss: 1.8062 - categorical_accuracy: 0.4327 - mean_squared_error: 0.0768 - mean_absolute_error: 0.1627 - val_loss: 1.7249 - val_categorical_accuracy: 0.6080 - val_mean_squared_error: 0.0742 - val_mean_absolute_error: 0.1613
# Epoch 85/100
# 49000/49000 [==============================] - 9s 187us/step - loss: 1.8005 - categorical_accuracy: 0.4325 - mean_squared_error: 0.0765 - mean_absolute_error: 0.1624 - val_loss: 1.7124 - val_categorical_accuracy: 0.6109 - val_mean_squared_error: 0.0738 - val_mean_absolute_error: 0.1608
# Epoch 86/100
# 49000/49000 [==============================] - 10s 201us/step - loss: 1.7878 - categorical_accuracy: 0.4382 - mean_squared_error: 0.0762 - mean_absolute_error: 0.1618 - val_loss: 1.6998 - val_categorical_accuracy: 0.6130 - val_mean_squared_error: 0.0734 - val_mean_absolute_error: 0.1602
# Epoch 87/100
# 49000/49000 [==============================] - 11s 222us/step - loss: 1.7744 - categorical_accuracy: 0.4418 - mean_squared_error: 0.0758 - mean_absolute_error: 0.1612 - val_loss: 1.6873 - val_categorical_accuracy: 0.6142 - val_mean_squared_error: 0.0730 - val_mean_absolute_error: 0.1596
# Epoch 88/100
# 49000/49000 [==============================] - 8s 158us/step - loss: 1.7645 - categorical_accuracy: 0.4450 - mean_squared_error: 0.0754 - mean_absolute_error: 0.1608 - val_loss: 1.6747 - val_categorical_accuracy: 0.6158 - val_mean_squared_error: 0.0726 - val_mean_absolute_error: 0.1590
# Epoch 89/100
# 49000/49000 [==============================] - 10s 209us/step - loss: 1.7530 - categorical_accuracy: 0.4469 - mean_squared_error: 0.0751 - mean_absolute_error: 0.1602 - val_loss: 1.6622 - val_categorical_accuracy: 0.6184 - val_mean_squared_error: 0.0721 - val_mean_absolute_error: 0.1584
# Epoch 90/100
# 49000/49000 [==============================] - 8s 166us/step - loss: 1.7405 - categorical_accuracy: 0.4512 - mean_squared_error: 0.0747 - mean_absolute_error: 0.1597 - val_loss: 1.6497 - val_categorical_accuracy: 0.6216 - val_mean_squared_error: 0.0717 - val_mean_absolute_error: 0.1578
# Epoch 91/100
# 49000/49000 [==============================] - 10s 205us/step - loss: 1.7300 - categorical_accuracy: 0.4567 - mean_squared_error: 0.0744 - mean_absolute_error: 0.1591 - val_loss: 1.6372 - val_categorical_accuracy: 0.6238 - val_mean_squared_error: 0.0713 - val_mean_absolute_error: 0.1572
# Epoch 92/100
# 49000/49000 [==============================] - 8s 157us/step - loss: 1.7186 - categorical_accuracy: 0.4594 - mean_squared_error: 0.0740 - mean_absolute_error: 0.1585 - val_loss: 1.6248 - val_categorical_accuracy: 0.6262 - val_mean_squared_error: 0.0709 - val_mean_absolute_error: 0.1566
# Epoch 93/100
# 49000/49000 [==============================] - 9s 193us/step - loss: 1.7081 - categorical_accuracy: 0.4619 - mean_squared_error: 0.0737 - mean_absolute_error: 0.1580 - val_loss: 1.6125 - val_categorical_accuracy: 0.6300 - val_mean_squared_error: 0.0705 - val_mean_absolute_error: 0.1560
# Epoch 94/100
# 49000/49000 [==============================] - 8s 169us/step - loss: 1.6944 - categorical_accuracy: 0.4691 - mean_squared_error: 0.0732 - mean_absolute_error: 0.1574 - val_loss: 1.6002 - val_categorical_accuracy: 0.6324 - val_mean_squared_error: 0.0701 - val_mean_absolute_error: 0.1553
# Epoch 95/100
# 49000/49000 [==============================] - 9s 191us/step - loss: 1.6863 - categorical_accuracy: 0.4689 - mean_squared_error: 0.0730 - mean_absolute_error: 0.1570 - val_loss: 1.5880 - val_categorical_accuracy: 0.6354 - val_mean_squared_error: 0.0696 - val_mean_absolute_error: 0.1547
# Epoch 96/100
# 49000/49000 [==============================] - 8s 166us/step - loss: 1.6704 - categorical_accuracy: 0.4776 - mean_squared_error: 0.0725 - mean_absolute_error: 0.1562 - val_loss: 1.5757 - val_categorical_accuracy: 0.6367 - val_mean_squared_error: 0.0692 - val_mean_absolute_error: 0.1541
# Epoch 97/100
# 49000/49000 [==============================] - 9s 175us/step - loss: 1.6647 - categorical_accuracy: 0.4776 - mean_squared_error: 0.0723 - mean_absolute_error: 0.1559 - val_loss: 1.5636 - val_categorical_accuracy: 0.6393 - val_mean_squared_error: 0.0688 - val_mean_absolute_error: 0.1534
# Epoch 98/100
# 49000/49000 [==============================] - 12s 240us/step - loss: 1.6533 - categorical_accuracy: 0.4802 - mean_squared_error: 0.0719 - mean_absolute_error: 0.1553 - val_loss: 1.5517 - val_categorical_accuracy: 0.6413 - val_mean_squared_error: 0.0684 - val_mean_absolute_error: 0.1528
# Epoch 99/100
# 49000/49000 [==============================] - 6s 131us/step - loss: 1.6419 - categorical_accuracy: 0.4862 - mean_squared_error: 0.0716 - mean_absolute_error: 0.1547 - val_loss: 1.5398 - val_categorical_accuracy: 0.6430 - val_mean_squared_error: 0.0680 - val_mean_absolute_error: 0.1522
# Epoch 100/100
# 49000/49000 [==============================] - 8s 157us/step - loss: 1.6303 - categorical_accuracy: 0.4897 - mean_squared_error: 0.0712 - mean_absolute_error: 0.1541 - val_loss: 1.5280 - val_categorical_accuracy: 0.6463 - val_mean_squared_error: 0.0676 - val_mean_absolute_error: 0.1516
# OK, training time=838.7

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

#print(history.history)
score = model.evaluate(X_test, y_test, verbose=0)

print(f"Training time: {t:0.1f} sec")
print(f"Test loss:     {score[0]}") # loss is score 0 by definition?
print(f"Test accuracy: {score[1]}")
print(f"All scores in history: {score}")
# Out:
# Training time: 838.7 sec
# Test loss:     1.527978215717134
# Test accuracy: 0.6462857142857142
# All scores in history: [1.527978215717134, 0.6462857142857142, 0.06757115110045388, 0.15155920931271144]

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
N=4
FX=60
FY=4
A=0.4
S=4


# Plot loss
plt.figure(figsize=(FX, FY))
ax = plt.subplot(1, N, 2)
plt.plot(history.history["loss"]    , "b--x", markerfacecolor=(0, 0, 1, A), markersize=S)
plt.plot(history.history["val_loss"], "g-s" , markerfacecolor=(0, 1, 0, A), markersize=S)
plt.legend(loc="best", labels=("loss(train)","loss(val)"))
plt.xlabel("epoch")
plt.ylabel("loss")
plt.title("Loss-vs-epoch plot")
plt.show()

# Plot all metrics + loss
plt.figure(figsize=(FX, FY))
ax = plt.subplot(1, N, 3)
plt.plot(history.history["mean_squared_error"],      "r:x", markerfacecolor=(1, 0, 0, A), markersize=S)
plt.plot(history.history["val_mean_squared_error"],  "r-x", markerfacecolor=(1, 0, 0, A), markersize=S)
plt.plot(history.history["mean_absolute_error"],     "b:o", markerfacecolor=(0, 0, 1, A), markersize=S)
plt.plot(history.history["val_mean_absolute_error"], "b-o", markerfacecolor=(0, 0, 1, A), markersize=S)
plt.xlabel("epoch")
plt.ylabel("error")
plt.xlim((0, EPOCHS))
plt.legend(loc="best", labels=("mean_squared_error(train)",  "mean_squared_error(val)", 
                               "mean_absolute_error(train)", "mean_absolute_error(val)", 
                               "loss(categorical_crossentropy,train)", "loss(categorical_crossentropy,val)"))
plt.title("Error-vs-epoch plot")
plt.show()

# Plot accuracy
plt.figure(figsize=(FX, FY))
ax = plt.subplot(1, N, 4)
plt.plot(history.history["categorical_accuracy"],     "m-x", markerfacecolor=(1, 0, 1, A), markersize=S)
plt.plot(history.history["val_categorical_accuracy"], "m:x", markerfacecolor=(1, 0, 1, A), markersize=S)
ax.set_ylim([0,1])
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.xlim((0, EPOCHS))
plt.legend(loc="lower right", labels=("categorical_accuracy",))
plt.title("Accuracy-vs-epoch plot")
plt.show()

# %% [markdown]
# #### Results
#
# The format is [Activation], [units], ... [units], lr=[learning rate], dropout=[dropout coeff], [notes]
#
# Adam optimizer is used unless otherwise noted.
#
#
# Sigmoid, 32, 10, lr=0.002, dropout = 0.2, 100 Epochs
# loss: 0.1741 - categorical_accuracy: 0.9443 - mean_squared_error: 0.0084 - mean_absolute_error: 0.0174 - val_loss: 0.1265 - val_categorical_accuracy: 0.9623 - val_mean_squared_error: 0.0056 - val_mean_absolute_error: 0.0110
# OK, training time=910.0
#
# Sigmoid, 1000, 500, 200, 10, lr=0.002, dropout = 0.5, not on input, 50 Epochs
# loss: 0.0150 - categorical_accuracy: 0.9952 - mean_squared_error: 7.2808e-04 - mean_absolute_error: 0.0013 - val_loss: 0.0961 - val_categorical_accuracy: 0.9822 - val_mean_squared_error: 0.0030 - val_mean_absolute_error: 0.0038
#
# Sigmoid, 1000, 500, 200, 10, lr=0.002, dropout = 0.2 including input, 50 Epochs
# 7s 148us/step - loss: 0.0130 - categorical_accuracy: 0.9956 - mean_squared_error: 6.6439e-04 - mean_absolute_error: 0.0012 - val_loss: 0.0707 - val_categorical_accuracy: 0.9845 - val_mean_squared_error: 0.0026 - val_mean_absolute_error: 0.0034
# OK, training time=367.6
#
# Sigmoid, 1000, 700, 300, 100, 10, lr=0.002, dropout = 0.2 including input, 75 Epochs
# 8s 173us/step - loss: 0.0093 - categorical_accuracy: 0.9970 - mean_squared_error: 4.6589e-04 - mean_absolute_error: 8.4933e-04 - val_loss: 0.0930 - val_categorical_accuracy: 0.9838 - val_mean_squared_error: 0.0028 - val_mean_absolute_error: 0.0035
# OK, training time=645.5
#
# Sigmoid, 2000, 1000, 500, 10 lr=0.002, dropout = 0.2 including input, 100 Epochs
# 14s 292us/step - loss: 0.0058 - categorical_accuracy: 0.9984 - mean_squared_error: 2.5794e-04 - mean_absolute_error: 4.6351e-04 - val_loss: 0.0922 - val_categorical_accuracy: 0.9856 - val_mean_squared_error: 0.0026 - val_mean_absolute_error: 0.0031
# OK, training time=1440.3
#
# Sigmoid, 2000, 1000, 500, 200, 100, 10 lr=0.001, dropout = 0.2 including input, 200 Epochs
# 15s 306us/step - loss: 0.0030 - categorical_accuracy: 0.9992 - mean_squared_error: 1.3906e-04 - mean_absolute_error: 2.6317e-04 - val_loss: 0.1075 - val_categorical_accuracy: 0.9851 - val_mean_squared_error: 0.0027 - val_mean_absolute_error: 0.0031
# OK, training time=3019.5
#
# #### Discussion
#
# It is observed that larger neural networks are prone to overfitting. To combat this we have tried to use dropout layers with limited success.
# The maximum achievable accuracy with MLPs seems to be around 98.5% based on our tests. From research we have found it to be possible to achieve higher accuracy using convolutional neural networks.
